# %% [markdown]
# <a href="https://colab.research.google.com/github/erenofc28/Rock-Vs-Mine-Sonar/blob/main/Rock_vs_Mine_Sonar_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Copy of sonar data.csv")

# %%
df.describe()
# Out:
#            0.0200      0.0371      0.0428      0.0207      0.0954      0.0986  \
# count  207.000000  207.000000  207.000000  207.000000  207.000000  207.000000
# mean     0.029208    0.038443    0.043837    0.054053    0.075105    0.104599
# std      0.023038    0.033040    0.038521    0.046583    0.055669    0.059247
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013300    0.016400    0.018900    0.024450    0.037700    0.066950
# 50%      0.022800    0.030800    0.034200    0.044100    0.062000    0.092100
# 75%      0.035800    0.048100    0.058200    0.065700    0.101050    0.134150
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#            0.1539      0.1601      0.3109      0.2111      0.1609      0.1582  \
# count  207.000000  207.000000  207.000000  207.000000  207.000000  207.000000
# mean     0.121591    0.134677    0.177361    0.208245    0.236376    0.250666
# ...

# %%
df.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  0.1609  0.1582  0.2238  0.0645  0.0660  0.2273  0.3100  0.2999  \
# 0  0.2872  0.4918  0.6552  0.6919  0.7797  0.7464  0.9444  1.0000  0.8874
# 1  0.6194  0.6333  0.7060  0.5544  0.5320  0.6479  0.6931  0.6759  0.7551
# 2  0.1264  0.0881  0.1992  0.0184  0.2261  0.1729  0.2131  0.0693  0.2281
# 3  0.4459  0.4152  0.3952  0.4256  0.4135  0.4528  0.5326  0.7306  0.6193
# 4  0.3039  0.2988  0.4250  0.6343  0.8198  1.0000  0.9988  0.9508  0.9025
#
# ...

# %%
df.isnull().sum()
# Out:
# 0.0200    0
# 0.0371    0
# 0.0428    0
# 0.0207    0
# 0.0954    0
#          ..
# 0.0180    0
# 0.0084    0
# 0.0090    0
# 0.0032    0
# R         0
# Length: 61, dtype: int64

# %%
df.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  0.1609  0.1582  0.2238  0.0645  0.0660  0.2273  0.3100  0.2999  \
# 0  0.2872  0.4918  0.6552  0.6919  0.7797  0.7464  0.9444  1.0000  0.8874
# 1  0.6194  0.6333  0.7060  0.5544  0.5320  0.6479  0.6931  0.6759  0.7551
# 2  0.1264  0.0881  0.1992  0.0184  0.2261  0.1729  0.2131  0.0693  0.2281
# 3  0.4459  0.4152  0.3952  0.4256  0.4135  0.4528  0.5326  0.7306  0.6193
# 4  0.3039  0.2988  0.4250  0.6343  0.8198  1.0000  0.9988  0.9508  0.9025
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
print(df["R"].unique())  # Should return ['R', 'M']
# Out:
# ['R' 'M']

# %%
df.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  0.1609  0.1582  0.2238  0.0645  0.0660  0.2273  0.3100  0.2999  \
# 0  0.2872  0.4918  0.6552  0.6919  0.7797  0.7464  0.9444  1.0000  0.8874
# 1  0.6194  0.6333  0.7060  0.5544  0.5320  0.6479  0.6931  0.6759  0.7551
# 2  0.1264  0.0881  0.1992  0.0184  0.2261  0.1729  0.2131  0.0693  0.2281
# 3  0.4459  0.4152  0.3952  0.4256  0.4135  0.4528  0.5326  0.7306  0.6193
# 4  0.3039  0.2988  0.4250  0.6343  0.8198  1.0000  0.9988  0.9508  0.9025
#
# ...

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# %%
X = df.drop(columns=["R"])
y = df["R"]

# %%
y = LabelEncoder().fit_transform(y)

# %%
y = pd.DataFrame(y)
y = y.astype(int)
y = pd.DataFrame(y)

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    "kernel":["poly","kernel"],
    "C":[0.5,0.6,0.4,0.7]
}

# %%
gridsearch = GridSearchCV(SVC(),params,scoring="accuracy",cv=5)

# %%
gridsearch.fit(X,y)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
print(gridsearch.best_params_)
print(gridsearch.best_score_)
# Out:
# {'C': 0.7, 'kernel': 'poly'}
# 0.6180023228803717

# %%
model = SVC(**gridsearch.best_params_)

# %%
y.head()
# Out:
#    0
# 0  1
# 1  1
# 2  1
# 3  1
# 4  1

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# %%
X = pd.DataFrame(X)

# %%
# from sklearn.feature_selection import SelectKBest , f_classif

# %%
# selector = SelectKBest(score_func = f_classif , k = 10)
# k_best = selector.fit_transform(X,y)
# X = X.loc[:,selector.get_support()]

# %%
x_train, x_test, y_train , y_test = train_test_split(X,y,stratify=y,random_state = 2, train_size = 0.8)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

# %%
y = pd.DataFrame(y)

# %%
# plt.figure(figsize=(8,6))
# sns.countplot(x = y)
# plt.show()

# %%
y_train = y_train.astype(int)
y_test = y_test.astype(int)

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(C=0.7, kernel='poly')

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
x_train.head()
# Out:
#            0         1         2         3         4         5         6   \
# 97   4.442241  5.930164  6.819572  8.012560  5.868354  1.260507  1.031765
# 117  0.308579  0.283891 -0.365285 -0.711262  1.184765  1.471999  0.215535
# 25  -0.613880 -0.195480  0.417997  1.096338  0.741796  1.164067  0.749972
# 28  -0.448533 -0.231888 -0.628114  0.175323 -1.208348 -0.434811  0.362910
# 68  -0.331050 -0.514050 -0.430342 -0.864047 -0.709558 -0.441578 -0.501906
#
#            7         8         9         10        11        12        13  \
# 97  -1.517336  0.131660  0.110512  0.409680 -0.176992  0.284243  0.198626
# 117  0.312721 -0.059825 -0.474985 -0.282620 -0.252033  0.090516  0.362362
# 25  -0.267541 -0.749512 -0.652792 -1.143848 -0.706561 -0.305453 -0.112351
# 28   0.122433  0.013041  0.327005  0.183438  0.859990  0.830653 -0.186277
# 68  -0.515386 -0.527525 -0.825391 -0.875374 -1.003863 -1.095264 -0.742247
#
# ...

# %%
y_pred = model.predict(x_train)
print("train score : ",accuracy_score(y_pred , y_train) * 100)
print(classification_report(y_pred,y_train))
# Out:
# train score :  92.12121212121212
#               precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93       101
#            1       0.83      1.00      0.91        64
#
#     accuracy                           0.92       165
#    macro avg       0.92      0.94      0.92       165
# weighted avg       0.93      0.92      0.92       165

# %%
y_pred = model.predict(x_test)
print("test score : ",accuracy_score(y_pred , y_test) * 100)
print(classification_report(y_pred,y_test))
# Out:
# test score :  88.09523809523809
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90        28
#            1       0.74      1.00      0.85        14
#
#     accuracy                           0.88        42
#    macro avg       0.87      0.91      0.88        42
# weighted avg       0.91      0.88      0.88        42

# %%
X.shape
# Out:
# (207, 60)

# %%
y_test.head()
# Out:
#      0
# 135  0
# 139  0
# 63   1
# 73   1
# 100  0

# %%
def pred(input):
  input = np.asarray(input)
  input = input.reshape(1,-1)
  input = scaler.transform(input)
  pred = model.predict(input)
  if pred[0]== 1:
    print("Rock")
  else:
    print("Mine")

# %%
# expected output : Mine
input =( 0.0094,0.0611,0.1136,0.1203,0.0403,0.1227,0.2495,0.4566,0.6587,0.5079,0.3350,0.0834,0.3004,0.3957,0.3769,0.3828,0.1247,0.1363,0.2678,0.9188,0.9779,0.3236,0.1944,0.1874,0.0885,0.3443,0.2953,0.5908,0.4564,0.7334,0.1969,0.2790,0.6212,0.8681,0.8621,0.9380,0.8327,0.9480,0.6721,0.4436,0.5163,0.3809,0.1557,0.1449,0.2662,0.1806,0.1699,0.2559,0.1129,0.0201,0.0480,0.0234,0.0175,0.0352,0.0158,0.0326,0.0201,0.0168,0.0245,0.0154)
pred(input)
# Out:
# Mine
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
X.shape
# Out:
# (207, 60)

# %%
df.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  0.1609  0.1582  0.2238  0.0645  0.0660  0.2273  0.3100  0.2999  \
# 0  0.2872  0.4918  0.6552  0.6919  0.7797  0.7464  0.9444  1.0000  0.8874
# 1  0.6194  0.6333  0.7060  0.5544  0.5320  0.6479  0.6931  0.6759  0.7551
# 2  0.1264  0.0881  0.1992  0.0184  0.2261  0.1729  0.2131  0.0693  0.2281
# 3  0.4459  0.4152  0.3952  0.4256  0.4135  0.4528  0.5326  0.7306  0.6193
# 4  0.3039  0.2988  0.4250  0.6343  0.8198  1.0000  0.9988  0.9508  0.9025
#
# ...

# %%
X.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.700189  0.420421  1.052950  0.319501  0.777810  2.600518  1.522475
# 1 -0.130894  0.599427  1.719130  1.167351  0.401466  2.087862  1.967839
# 2 -0.835792 -0.647546  0.480451 -0.722021 -0.983262 -1.147115 -0.190961
# 3  2.044717  0.854283  0.110929 -0.315311 -0.289998 -0.671681 -0.011196
# 4 -0.026465  0.208041 -0.419933 -0.788730 -0.660939 -0.094732 -0.024152
#
#          7         8         9         10        11        12        13  \
# 0  2.506911  1.324632  0.587392  1.926256  2.891076  2.968747  2.944876
# 1  2.847551  3.240336  3.058831  2.993364  3.254127  1.993016  1.431536
# 2 -0.083126 -0.996071 -0.608898 -1.118207 -0.367809 -1.810564 -0.437380
# 3  1.315846  1.516965  1.768058  1.348584  1.032940  1.079021  0.707553
# 4  0.571138  0.280782  0.711633  0.470766  1.245911  2.560004  3.189870
#
#          14        15        16        17        18        19        20  \
# ...

# %%
y.head()
# Out:
#    0
# 0  1
# 1  1
# 2  1
# 3  1
# 4  1
